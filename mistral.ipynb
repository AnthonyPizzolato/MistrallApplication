# %%
# %pip install torch
# %pip install vllm
# %pip install transformers huggingface_hub
# %pip install huggingface_hub
# %pip install ipywidgets==7.7.1

# %pip install PyPDF2
# %pip install python-docx
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting vllm
#   Downloading vllm-0.6.3.post1-cp38-abi3-manylinux1_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from vllm) (4.66.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from vllm) (9.0.0)
# Collecting transformers>=4.45.2 (from vllm)
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from vllm) (0.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from vllm) (3.20.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from vllm) (3.10.10)
# Collecting openai>=1.40.0 (from vllm)
#   Downloading openai-1.52.2-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn[standard] (from vllm)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.9.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from vllm) (10.4.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (0.21.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Downloading prometheus_fastapi_instrumentator-7.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting lm-format-enforcer==0.10.6 (from vllm)
#   Downloading lm_format_enforcer-0.10.6-py3-none-any.whl.metadata (16 kB)
# Collecting outlines<0.1,>=0.0.43 (from vllm)
#   Downloading outlines-0.0.46-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.10/dist-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from vllm) (3.16.1)
# Collecting partial-json-parser (from vllm)
#   Downloading partial_json_parser-0.2.1.1.post4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.10/dist-packages (from vllm) (24.0.1)
# Collecting msgspec (from vllm)
#   Downloading msgspec-0.18.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.10.0 (from vllm)
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from vllm) (8.5.0)
# Collecting mistral-common>=1.4.4 (from mistral-common[opencv]>=1.4.4->vllm)
#   Downloading mistral_common-1.4.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from vllm) (0.8.0)
# Collecting compressed-tensors==0.6.0 (from vllm)
#   Downloading compressed_tensors-0.6.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting ray>=2.9 (from vllm)
#   Downloading ray-2.38.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting nvidia-ml-py (from vllm)
#   Downloading nvidia_ml_py-12.560.30-py3-none-any.whl.metadata (8.6 kB)
# Collecting torch==2.4.0 (from vllm)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.19 (from vllm)
#   Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting xformers==0.0.27.post2 (from vllm)
#   Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting fastapi!=0.113.*,!=0.114.0,>=0.107.0 (from vllm)
#   Downloading fastapi-0.115.3-py3-none-any.whl.metadata (27 kB)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.10.6->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lm-format-enforcer==0.10.6->vllm) (24.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->vllm) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.0->vllm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.0->vllm)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.0->vllm)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.0->vllm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.0->vllm)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.0->vllm)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.0->vllm)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.0->vllm)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.0->vllm)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.0->vllm)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.0->vllm)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch==2.4.0->vllm)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->vllm) (12.6.77)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm)
#   Downloading starlette-0.41.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /usr/local/lib/python3.10/dist-packages (from mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (4.23.0)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mistral-common[opencv]>=1.4.4->vllm) (4.10.0.84)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.40.0->vllm) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.40.0->vllm)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.40.0->vllm)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->vllm) (1.3.1)
# Collecting lark (from outlines<0.1,>=0.0.43->vllm)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm) (3.1.0)
# Collecting diskcache (from outlines<0.1,>=0.0.43->vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm) (0.60.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from outlines<0.1,>=0.0.43->vllm) (0.35.1)
# Collecting datasets (from outlines<0.1,>=0.0.43->vllm)
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting pycountry (from outlines<0.1,>=0.0.43->vllm)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting pyairports (from outlines<0.1,>=0.0.43->vllm)
#   Downloading pyairports-2.1.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9->vllm) (2.23.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->vllm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->vllm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->vllm) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.6.0->vllm) (2024.9.11)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.19.1->vllm) (0.24.7)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.2->vllm) (0.4.5)
# Collecting tokenizers>=0.19.1 (from vllm)
#   Downloading tokenizers-0.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->vllm) (4.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->vllm) (3.20.2)
# Collecting h11>=0.8 (from uvicorn[standard]->vllm)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vllm)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]->vllm)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.40.0->vllm) (1.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.40.0->vllm)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (0.20.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->vllm) (0.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->outlines<0.1,>=0.0.43->vllm)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (2.2.2)
# Collecting xxhash (from datasets->outlines<0.1,>=0.0.43->vllm)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->outlines<0.1,>=0.0.43->vllm)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0->vllm) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->outlines<0.1,>=0.0.43->vllm) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0->vllm) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->outlines<0.1,>=0.0.43->vllm) (1.16.0)
# Downloading vllm-0.6.3.post1-cp38-abi3-manylinux1_x86_64.whl (194.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 MB 6.2 MB/s eta 0:00:00
# Downloading compressed_tensors-0.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 3.3 MB/s eta 0:00:00
# Downloading gguf-0.10.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.1 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.6-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.3 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.0 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 111.9 MB/s eta 0:00:00
# Downloading xformers-0.0.27.post2-cp310-cp310-manylinux2014_x86_64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 93.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 101.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 90.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 53.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 33.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.2 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.4 MB/s eta 0:00:00
# Downloading fastapi-0.115.3-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 9.8 MB/s eta 0:00:00
# Downloading mistral_common-1.4.4-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 106.9 MB/s eta 0:00:00
# Downloading openai-1.52.2-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 33.5 MB/s eta 0:00:00
# Downloading outlines-0.0.46-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 11.7 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.0.0-py3-none-any.whl (19 kB)
# Downloading ray-2.38.0-cp310-cp310-manylinux2014_x86_64.whl (66.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 MB 33.1 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.6 MB/s eta 0:00:00
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 118.4 MB/s eta 0:00:00
# Downloading tokenizers-0.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.6 MB/s eta 0:00:00
# Downloading msgspec-0.18.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 23.7 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.560.30-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.6 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post4-py3-none-any.whl (9.9 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 37.3 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 8.1 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 31.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.41.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.3 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 99.3 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 37.5 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 18.2 MB/s eta 0:00:00
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 38.6 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.2 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 12.2 MB/s eta 0:00:00
# Downloading pyairports-2.1.1-py3-none-any.whl (371 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 29.8 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 115.8 MB/s eta 0:00:00
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.2 MB/s eta 0:00:00
# Installing collected packages: pyairports, nvidia-ml-py, xxhash, websockets, uvloop, triton, python-dotenv, pycountry, partial-json-parser, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, msgspec, lark, jiter, interegular, httptools, h11, gguf, diskcache, dill, watchfiles, uvicorn, tiktoken, starlette, nvidia-cusolver-cu12, nvidia-cudnn-cu12, multiprocess, httpcore, torch, tokenizers, prometheus-fastapi-instrumentator, lm-format-enforcer, httpx, fastapi, xformers, transformers, torchvision, ray, openai, mistral-common, datasets, compressed-tensors, outlines, vllm
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.3.3
#     Uninstalling nvidia-cublas-cu12-12.6.3.3:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.3.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.0.50
#     Uninstalling nvidia-cudnn-cu12-9.5.0.50:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.0.50
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.0+cu121
#     Uninstalling torchvision-0.20.0+cu121:
#       Successfully uninstalled torchvision-0.20.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 2.4.0 which is incompatible.
# Successfully installed compressed-tensors-0.6.0 datasets-3.0.2 dill-0.3.8 diskcache-5.6.3 fastapi-0.115.3 gguf-0.10.0 h11-0.14.0 httpcore-1.0.6 httptools-0.6.4 httpx-0.27.2 interegular-0.3.3 jiter-0.6.1 lark-1.2.2 lm-format-enforcer-0.10.6 mistral-common-1.4.4 msgspec-0.18.6 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-ml-py-12.560.30 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 openai-1.52.2 outlines-0.0.46 partial-json-parser-0.2.1.1.post4 prometheus-fastapi-instrumentator-7.0.0 pyairports-2.1.1 pycountry-24.6.1 python-dotenv-1.0.1 ray-2.38.0 starlette-0.41.0 tiktoken-0.7.0 tokenizers-0.20.1 torch-2.4.0 torchvision-0.19.0 transformers-4.46.0 triton-3.0.0 uvicorn-0.32.0 uvloop-0.21.0 vllm-0.6.3.post1 watchfiles-0.24.0 websockets-13.1 xformers-0.0.27.post2 xxhash-3.5.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.8.30)
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1) (3.0.13)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets==7.7.1)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.1.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.1) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.7.1) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.0.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.1) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.20.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1) (1.2.2)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.5 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
from huggingface_hub import notebook_login
#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
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import PyPDF2
from docx import Document
from vllm import LLM, SamplingParams
import torch
#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

# Load the Vllm model

llm =LLM(
    model="mistralai/Mistral-7B-v0.1", device= "cuda",max_model_len= 19456

    )  # Replace with your model name
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# INFO 10-25 01:51:57 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='mistralai/Mistral-7B-v0.1', speculative_config=None, tokenizer='mistralai/Mistral-7B-v0.1', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=19456, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=mistralai/Mistral-7B-v0.1, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, mm_processor_kwargs=None)
# /usr/local/lib/python3.10/dist-packages/vllm/transformers_utils/tokenizer_group/tokenizer_group.py:23: FutureWarning: It is strongly recommended to run mistral models with `--tokenizer_mode "mistral"` to ensure correct encoding and decoding.
#   self.tokenizer = get_tokenizer(self.tokenizer_id, **tokenizer_config)
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# INFO 10-25 01:51:58 selector.py:247] Cannot use FlashAttention-2 backend due to sliding window.
# INFO 10-25 01:51:58 selector.py:115] Using XFormers backend.
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:211: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_fwd")
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:344: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_bwd")
# INFO 10-25 01:52:00 model_runner.py:1056] Starting to load model mistralai/Mistral-7B-v0.1...
# INFO 10-25 01:52:00 selector.py:247] Cannot use FlashAttention-2 backend due to sliding window.
# INFO 10-25 01:52:00 selector.py:115] Using XFormers backend.
# INFO 10-25 01:52:01 weight_utils.py:243] Using model weights format ['*.safetensors']
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 10-25 01:54:48 model_runner.py:1067] Loading model weights took 13.4966 GB
# INFO 10-25 01:54:54 gpu_executor.py:122] # GPU blocks: 2058, # CPU blocks: 2048
# INFO 10-25 01:54:54 gpu_executor.py:126] Maximum concurrency for 19456 tokens per request: 1.69x
# INFO 10-25 01:54:56 model_runner.py:1395] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 10-25 01:54:56 model_runner.py:1399] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 10-25 01:55:24 model_runner.py:1523] Graph capturing finished in 27 secs.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function to extract text from PDF
def extract_text_from_pdf(file_path):
    text = ""
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page_num in range(len(reader.pages)):
            text += reader.pages[page_num].extract_text()
    return text

# Function to extract text from Word documents
def extract_text_from_docx(file_path):
    doc = Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs])
    return text

# Function to generate a study guide using Vllm
def generate_study_guide(text, questions=False):
    # Split the document text into smaller chunks
    print("here")
    chunks = [text[i:i+5000] for i in range(0, len(text), 1500)]
    # Create study guide with summaries
    study_guide = "Study Guide:\n"
    print(len(chunks))
    for i, chunk in enumerate(chunks):
        sampling_params = SamplingParams(temperature=0.7, max_tokens=200)
        prompt = f"Create a concise summary of the following content: {chunk}"
        response = llm.generate(prompt, sampling_params)[0]
        print(response.outputs[0].text)

        study_guide += f"\nSection {i+1} Summary:\n" + response.outputs[0].text + "\n"

    if questions:
        study_guide += "\nQuiz Questions:\n"
        for i, chunk in enumerate(chunks):
            prompt = f"Generate 3 quiz questions from the following content: {chunk}"
            response = llm.generate(prompt, sampling_params)[0]

            print(response.outputs[0].text)
            study_guide += f"\nSection {i+1} Questions:\n" + response.outputs[0].text + "\n"

    return study_guide

# Main chatbot interaction
def chatbot():
    print(" Study Guide Chatbot!")
    while True:
        user_input = input("Please upload your study guide (PDF/DOCX) or type 'exit'   to quit: ").strip()

        if user_input.lower() == 'exit':
            print("Goodbye!")
            break

        # Load the document and extract text
        if user_input.endswith('.pdf'):
            text = extract_text_from_pdf(user_input)
        elif user_input.endswith('.docx'):
            text = extract_text_from_docx(user_input)
        else:
            print("Unsupported file format. Please upload a PDF or DOCX file.")
            continue

        # Generate the study guide
        include_questions = input("Do you want quiz question information from the study guide?: ").strip().lower() == 'yes'
        study_guide = generate_study_guide(text, questions=include_questions)

        print(study_guide)

# Run the chatbot

chatbot()
# Out:
#  Study Guide Chatbot!
# Please upload your study guide (PDF/DOCX) or type 'exit'   to quit: wines.docx
# Do you want quiz question information from the study guide?: yes
# here
# 10
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.11s/it, est. speed input: 110.15 toks/s, output: 16.51 toks/s]
# exchange; reds do not
# reds also need a fining stage; whites don’t
# white wines can be aged in oak, but this is not the norm; red wines can too, but this is the norm
#
# What are the major differences between how white and red wines are made?
#
# red wines ferment with juice, skins, and pulp; white with just juice
# white wines’ pressing stage comes BEFORE fermentation; red wines’ pressing comes AFTER differences in cellar operations:
# red wines require racking to remove suspended particles; whites do not whites require a cold stabilization stage before the ion-exchange; reds do not
# reds also need a fining stage; whites don’t
# white wines can be aged in oak, but this is not the norm; reds can too, but this is the norm
#
# What are the major differences between how white and
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.15s/it, est. speed input: 112.64 toks/s, output: 16.47 toks/s]
# ation tanks)
# materials (such as oak barrels)
# age of vines (younger vines are lower quality)
#
#
#
# why are grapes harvested by hand?
#
# it allows the winemaker to pick the grapes at the optimum time,
# taking into account the weather and the state of ripeness of the grapes.
#
#
#
# How are grapes harvested?
#
# Grapes are harvested by hand, using a special tool called a clipper. The clipper cuts the grape from the vine, and leaves the stems.
#
#
#
# Why are grapes harvested at night?
#
# Grapes are harvested at night to protect them from the heat of the day. Grapes are also harvested at night because they are less likely to be damaged by the sun.
#
#
#
# How is the grape harvest used to determine the quality of the wine?
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.21s/it, est. speed input: 111.51 toks/s, output: 16.39 toks/s]
# ine Aging
# Wine aging is the period of time that a wine is allowed for the purpose of developing a more complex character.
# Aging is done for 2 purposes:
# To stabilize the wine (preventing spoilage)
# To refine and mellow the wine (integrate flavors)
#
#
# The fermentation process, cellar operations and aging of a wine are not in themselves responsible for the total bouquet of flavors of a wine—more than 50% of the wines bouquet is influenced by the grape variety and the original juice.
#
# Why is it important to know the amount of alcohol in a wine?
#
# Shows the intensity of a wine; the higher the alcohol content, the more concentrated the wine
# shows how the wine will be with food-the higher the alcohol the more astringent the wine will be
# wines with 13-14% alcohol or higher are capable
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.14s/it, est. speed input: 113.25 toks/s, output: 16.47 toks/s]
# yric acids and diacetyl can cause buttery, sweaty, and/or goaty flavors).
#
# Phenolics- affect taste and texture
# Tannins: extracted from skins, seeds, and stalks (responsible for the astringent taste in red wines).
# Phenolics: yellow pigments and brown pigments
# Yellow pigments: contribute to color
# Brown pigments: contribute to color and bitterness
#
# Glycerol- affects body, mouthfeel, and storage life
# Glycerol: a natural, sweet byproduct of fermentation
#
# Residual sugar- affects sweetness
# Residual Sugar: the amount of sugar left in wine after fermentation
# Sweetness (lack of sugar)
# Alcohol (more alcohol means less sugar)
# Climate and ripeness of grapes (affects sugar levels)
# Yeast
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.15s/it, est. speed input: 112.59 toks/s, output: 16.46 toks/s]
#  in cool growing regions.
# Malolactic Fermentation: the conversion of Malic acid to lactic acid, which is softer, by bacteria. This process can add buttery flavors to the wine, and can help soften the high acidity levels in some wines.
# Acidification: the addition of acid (usually tartaric) to the unfinished wine, sometimes done in hot climates where the natural acidity in the grapes is low.
# Amelioration: the addition of water and sugar to the grape must to dilute acidity and to boost the alcohol in the finished wine.
#
#
# How are the components of wine evaluated for production?
#
# Yields per acre: there is a price differential depending on yields; top quality wines usually originate from 1.0-1.5 tons of grapes/acre yields.
# Soil type, topography, and microclimate (water
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.15s/it, est. speed input: 113.10 toks/s, output: 16.46 toks/s]
# ), oxidized: brown.
# Rose – pale ruby to pale orange/brown
#
# Composed of:
# Body: light, medium, full
# Dryness: dry, medium dry, semi- sweet, sweet
# Acidity: low, medium, high
# Structure: soft, medium, firm
# Finish: short, medium, long
# Taste: fruity, vegetal, earthy, herbal, nutty, smoky, spice
# Structure
# Balance: harmonious, unbalanced
# Flaws: oxidized, maderized, other
#
# When tasting wine, what do we look for? What are the five attributes of wine?
# When tasting wine, look for appearance, aroma, taste, and aftertaste.
#
# Appearance
#
# Brilliant: wines free of any visible solids and having a sparkling clarity.
# Clear: wines free of any solids but
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.14s/it, est. speed input: 107.45 toks/s, output: 16.48 toks/s]
# Tannins
# dry
# soft
#
# Body
# light
# medium
# full
#
# Aftertaste
# Lingering
# Short
# Astringent
#
# Complexity
# Simple
# Complex
#
# Development
# Young
# Mature
# Over-the-Hill
#
# Alcohol
# Low
# Medium
# High
#
# Aroma
# Woody
# Flowery
# Fruity
# Spicy
#
# Finish
# Smooth
# Bittersweet
# Hot
# Sharp
#
# Smooth
# Astringent
# Flat
# Tart
#
# Flavor
# Bitter
# Sweet
# Dry
# Sour
#
#
# How do we evaluate wines? What are the stages of taste?
# Appearance
# Brilliant: wines free of any visible solids and having a sparkling clarity.
# Clear: wines free of any solids but lacking the sparkling clarity of brilliant wines.
# D
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.01s/it, est. speed input: 75.04 toks/s, output: 16.66 toks/s]
# How are wines categorized? Classification of wine
#
# The classification of wine can be based on:
#
# - Price
# - Region of production
# - Type of grape used
# - Amount of alcohol
# - Age
# - Method of production
# - Type of packaging
#
# The classification of wine can be divided into the following:
#
# - Vintage wine
# - Non-vintage wine
# - Aged wine
# - Table wine
# - Wine for cooking
# - Sparkling wine
# - Fortified wine
# - Still wine
# - Fresh wine
# - Sweet wine
# - Dessert wine
# - Dry wine
# - Light wine
# - Red wine
# - White wine
# - Rose wine
# - Champagne
# - Port
# - Sherry
# - Madeira
# - Wine cocktail
# - Draft beer
# - Bottled beer
# - Canned beer
#
# Wine is made from fermented grapes or other fruits
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.69s/it, est. speed input: 110.65 toks/s, output: 16.42 toks/s]
# Balanced- sugar and acid are in balance
#
# Unbalanced- sweetness is greater than acidity
#
# Residual Sugar
# Dry
# Semi-Dry
# Semi- Sweet
# Sweet
# Structure
# Full-bodied
# Medium-bodied
# Light-bodied
# Alcohol
# High
# Medium
# Low
# Processed prompts: 100%|██████████| 1/1 [00:11<00:00, 11.68s/it, est. speed input: 10.45 toks/s, output: 17.13 toks/s]
# What is the most predominant flavor in the aroma?
# What is the most predominant flavor in the palate?
# What is the most predominant flavor in the finish?
# What is the most predominant flavor in the aftertaste?
# What is the most predominant flavor in the overall beer?
#
# You must identify the following chemical compounds: volatile esters, diacetyl, acetaldehyde, sulfur compounds, DMS, dimethyl sulfide,
#
# What are the predominant chemical compounds in the aroma?
# What are the predominant chemical compounds in the palate?
# What are the predominant chemical compounds in the finish?
# What are the predominant chemical compounds in the aftertaste?
# What are the predominant chemical compounds in the overall beer?
#
# What is the body of the beer?
# What is the texture of the beer?
# What is the
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.14s/it, est. speed input: 109.95 toks/s, output: 16.47 toks/s]
# exchange stage for fining; reds do not white wines require malo-lactic fermentation to make them softer, but red wines do not
#
# White wine grapes are generally picked earlier than red wine grapes.
#
# What are the main differences between white and red wines in terms of aging and storage?
#
# Red wines are more stable than whites and can be aged for many years. White wines are not as stable and are generally consumed within three to five years of the vintage date.
#
# Furthermore, red wines are best stored on their sides and white wines are generally best stored on their sides.
#
# Red wines can be stored flat or on their sides.
#
# What are the primary characteristics of a wine?
#
# Appearance (color)
# Aroma (smell)
# Taste
# Finish
#
# How does a wine’s color relate to its varietal type?
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.14s/it, est. speed input: 112.74 toks/s, output: 16.47 toks/s]
# ers, barrels, etc)
# vineyard management (techniques for harvesting grapes, fermenting, and aging)
#
#
# How many grape varieties exist and what are the major ones?
#
# There are around 5,000 grape varieties. The major ones are Chardonnay, Cabernet Sauvignon, Sauvignon Blanc, Merlot, Pinot Noir, Syrah, and Riesling.
#
# What are the different types of still white wines?
#
# Dry: A dry white wine is a wine that has little to no residual sugar.
#
# Off-Dry: An off-dry wine is a white wine that is semi sweet.
#
# Sweet: A sweet wine is a wine that contains a high amount of residual sugar.
#
# Fortified: A fortified wine is a wine that has had brandy or neutral spirit added to it
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.14s/it, est. speed input: 112.20 toks/s, output: 16.48 toks/s]
# ine color
# White: Greenish-white, greenish-gold, amber, golden, yellow, and orange.
# Red: Red, garnet, ruby, raspberry, plum, and purple.
# Rosé: Pink, light red, salmon, and orange.
#
# What are the major differences between how white and red wines are made?
#
# Red Wine
# Most red wines are best at cool room temperature. 62-65 degrees F (16-18 degrees C).
# Red served at actual room temperature (70 degrees F) can taste flat, flabby, lifeless, and often too hot with a burning sensation from the alcohol (room temperature in the past use to be much lower, 62-65).
# Red served too cold tastes overly tannic and acidic, decidedly unpleasant.
# Light, fruity red wines are most delightful
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.18s/it, est. speed input: 112.95 toks/s, output: 16.42 toks/s]
# yric acid may be produced)
#
# Tannins: give a feeling of dryness in the mouth
# come from skin, stalk, pips.
# add to structural balance of the wine
#
# Grape Ester- contributes to aromas and flavors
#
# Body, texture, structure, and mouthfeel
# Body: refers to the perceivable weight of the wine in the mouth
# Texture: refers to the tactile feeling of the wine in the mouth
# Structure: refers to the perception of balance, harmony, and complexity of the wine in the mouth
# Mouthfeel: refers to the overall experience of a wine in the mouth
#
# What are the major varietal categories of wine and grapes?
#
# RED TABLE WINES
# Cabernet Sauvignon:
# Zinfandel
# Merlot
#
# WHITE TABLE WINES
# Chardonnay
# Sauvignon Blanc
# Ries
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.16s/it, est. speed input: 112.63 toks/s, output: 16.45 toks/s]
#  in cool growing regions.
#
# Acidification - the addition of acid to the unfinished wine (sometimes done in hot climates where the natural acidity in the grapes is low).
#
# Amelioration - the addition of water and sugar to the grape must to dilute acidity and to boost the alcohol in the finished wine.
#
# Adding yeast: ferments grape’s sugar and converts it to carbon dioxide and alcohol
# Removing sulfur dioxide
# Tannin: Removing tannin
# Filtration: passing wine through a filter to remove sediment that might make wine cloudy and/or to remove yeast, bacteria and other unwanted substances; also to stabilize the wine and to protect it from spoilage
# Malolactic Fermentation: a process in which malic acid can be converted to a softer lactic acid, which contributes to buttery flavors
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.15s/it, est. speed input: 113.19 toks/s, output: 16.46 toks/s]
# ).
#
# Bouquet: fragrances developed in the wine making and aging process.
# Flavor: the color and texture of the wine
# o Fresh: fresh wines are clean, crisp, and refreshing.
# o Dry: dry wine is wine that has no residual sugar
# o Light: light wines are usually low in alcohol content
# o Bitter: bitter wines have a harsh, dry aftertaste
# o Sweet: sweet wines have a residual sugar (honey).
# o Tart: tart wines are high in acidity and only slightly sweet
# o Fruity: fruity wines give the impression of tasting like certain fruits
# o Astringent: astringent wines have a dry, puckering taste
# o Full: full wines are rich, round and full-bodied
# o Soft: soft wines lack the rough edges of harsh wines
# o Rich: rich wines
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.15s/it, est. speed input: 107.46 toks/s, output: 16.47 toks/s]
# How do we evaluate wines? What are the stages of taste?
#
# Bitter/Harsh
# Astringent
# Fruity
# Flavors: Sensation of taste (sweet, sour, bitter, salty, umami)
# Taste: texture of wine
# Flavors and Taste:
#
# Sweetness:
#
# The wine’s perception of sweetness or lack of sweetness
#
# The sweetness is balanced with the acids and tannins in the wine (sugar/acid balance)
#
# Residual sugar: residual sugar in wine (<.4% is technically dry. Residual sugar balances high acidity. High acidity can appear dry to the taste even though they have residual sugar.
#
# Acidity:
#
# The wine’s perception of acidity or lack of acidity
#
# Balanced with the sweetness in the wine
#
# The wine’s
# Processed prompts: 100%|██████████| 1/1 [00:12<00:00, 12.01s/it, est. speed input: 75.12 toks/s, output: 16.66 toks/s]
# How do we evaluate wines? What are the characteristics of Wine?
#
# Acidity: slightly acidic, medium acidic, high acidic
# pH: 3.0 (lemon juice), 3.5 (tomato juice), 4.0 (water), 4.5 (cow’s milk), 5.0 (ripe fruit), 6.0 (filtered water), 7.0 (pure water), 8.0 (alkaline water)
# Tannin: slightly tannic, medium tannic, high tannic
# Body: light-bodied, medium-bodied, full-bodied
# Alcohol: dry, medium dry, medium sweet, sweet
# Flavors: fruity, earthy, herbal, spicy
# Aromas: fruity, floral, earthy, spicy, herbal, toasty
# Processed prompts: 100%|██████████| 1/1 [00:11<00:00, 11.93s/it, est. speed input: 43.58 toks/s, output: 16.76 toks/s]
# Other factors:
# Purity
# Astringency
# Tannin
# Bitterness
# Finish
# Aroma
# Complexity
# Body
#
# Balance
# Taste
# Flavor
#
# Mouthfeel
#
# Alcohol
#
# Oak
#
# Acidity
#
# Tannin
#
# Bitterness
#
# Fruit
#
# Citrus
#
# Berry
#
# Floral
#
# Spice
#
# Earth
#
# Herb
#
# Mineral
#
# Caramel
#
# Vanilla
#
# Coffee
#
# Smoke
#
# Nutty
#
# Malt
#
# Corn
#
# Oily
#
# Alcohol
#
# Heat
#
# Astringency
#
# Bitterness
#
# Sweetness
#
# Balance
#
# Body
#
# Taste
#
# Flavor
#
# Mouthfeel
#
# Acidity
#
# Oak
#
# Tannin
#
# Bitterness
# Processed prompts: 100%|██████████| 1/1 [00:11<00:00, 11.69s/it, est. speed input: 10.53 toks/s, output: 17.12 toks/s]
# Compare with these categories:
#
# - intensity
# - sweet
# - acidic
# - bitter
# - astringent
#
# ### Flavors
#
# Based on the 5 basic tastes, there are 3 main flavor types: sweet, sour, and salty.
#
# - Sweetness reflects natural sugars and sweeteners. It can also be used to mask astringency or bitterness.
# - Acidic flavors come from acids like citric, lactic or acetic acid, and are often used to add freshness.
# - Salty flavors come from dissolved salts, and are generally used to add a savory taste.
#
# Various ingredients also have other flavor characteristics that are more difficult to describe.
#
# - Astringency comes from tannins, which are found in red wine and some fruits like grapes, cherries and cranberries.
# - Bitterness comes from acids or al
# Study Guide:
#
# Section 1 Summary:
# exchange; reds do not
# reds also need a fining stage; whites don’t
# white wines can be aged in oak, but this is not the norm; red wines can too, but this is the norm
#
# What are the major differences between how white and red wines are made?
#
# red wines ferment with juice, skins, and pulp; white with just juice
# white wines’ pressing stage comes BEFORE fermentation; red wines’ pressing comes AFTER differences in cellar operations:
# red wines require racking to remove suspended particles; whites do not whites require a cold stabilization stage before the ion-exchange; reds do not
# reds also need a fining stage; whites don’t
# white wines can be aged in oak, but this is not the norm; reds can too, but this is the norm
#
# What are the major differences between how white and
#
# Section 2 Summary:
# ation tanks)
# materials (such as oak barrels)
# age of vines (younger vines are lower quality)
#
#
#
# why are grapes harvested by hand?
#
# it allows the winemaker to pick the grapes at the optimum time,
# taking into account the weather and the state of ripeness of the grapes.
#
#
#
# How are grapes harvested?
#
# Grapes are harvested by hand, using a special tool called a clipper. The clipper cuts the grape from the vine, and leaves the stems.
#
#
#
# Why are grapes harvested at night?
#
# Grapes are harvested at night to protect them from the heat of the day. Grapes are also harvested at night because they are less likely to be damaged by the sun.
#
#
#
# How is the grape harvest used to determine the quality of the wine?
#
# Section 3 Summary:
# ine Aging
# Wine aging is the period of time that a wine is allowed for the purpose of developing a more complex character.
# Aging is done for 2 purposes:
# To stabilize the wine (preventing spoilage)
# To refine and mellow the wine (integrate flavors)
#
#
# The fermentation process, cellar operations and aging of a wine are not in themselves responsible for the total bouquet of flavors of a wine—more than 50% of the wines bouquet is influenced by the grape variety and the original juice.
#
# Why is it important to know the amount of alcohol in a wine?
#
# Shows the intensity of a wine; the higher the alcohol content, the more concentrated the wine
# shows how the wine will be with food-the higher the alcohol the more astringent the wine will be
# wines with 13-14% alcohol or higher are capable
#
# Section 4 Summary:
# yric acids and diacetyl can cause buttery, sweaty, and/or goaty flavors).
#
# Phenolics- affect taste and texture
# Tannins: extracted from skins, seeds, and stalks (responsible for the astringent taste in red wines).
# Phenolics: yellow pigments and brown pigments
# Yellow pigments: contribute to color
# Brown pigments: contribute to color and bitterness
#
# Glycerol- affects body, mouthfeel, and storage life
# Glycerol: a natural, sweet byproduct of fermentation
#
# Residual sugar- affects sweetness
# Residual Sugar: the amount of sugar left in wine after fermentation
# Sweetness (lack of sugar)
# Alcohol (more alcohol means less sugar)
# Climate and ripeness of grapes (affects sugar levels)
# Yeast
#
# Section 5 Summary:
#  in cool growing regions.
# Malolactic Fermentation: the conversion of Malic acid to lactic acid, which is softer, by bacteria. This process can add buttery flavors to the wine, and can help soften the high acidity levels in some wines.
# Acidification: the addition of acid (usually tartaric) to the unfinished wine, sometimes done in hot climates where the natural acidity in the grapes is low.
# Amelioration: the addition of water and sugar to the grape must to dilute acidity and to boost the alcohol in the finished wine.
#
#
# How are the components of wine evaluated for production?
#
# Yields per acre: there is a price differential depending on yields; top quality wines usually originate from 1.0-1.5 tons of grapes/acre yields.
# Soil type, topography, and microclimate (water
#
# Section 6 Summary:
# ), oxidized: brown.
# Rose – pale ruby to pale orange/brown
#
# Composed of:
# Body: light, medium, full
# Dryness: dry, medium dry, semi- sweet, sweet
# Acidity: low, medium, high
# Structure: soft, medium, firm
# Finish: short, medium, long
# Taste: fruity, vegetal, earthy, herbal, nutty, smoky, spice
# Structure
# Balance: harmonious, unbalanced
# Flaws: oxidized, maderized, other
#
# When tasting wine, what do we look for? What are the five attributes of wine?
# When tasting wine, look for appearance, aroma, taste, and aftertaste.
#
# Appearance
#
# Brilliant: wines free of any visible solids and having a sparkling clarity.
# Clear: wines free of any solids but
#
# Section 7 Summary:
# Tannins
# dry
# soft
#
# Body
# light
# medium
# full
#
# Aftertaste
# Lingering
# Short
# Astringent
#
# Complexity
# Simple
# Complex
#
# Development
# Young
# Mature
# Over-the-Hill
#
# Alcohol
# Low
# Medium
# High
#
# Aroma
# Woody
# Flowery
# Fruity
# Spicy
#
# Finish
# Smooth
# Bittersweet
# Hot
# Sharp
#
# Smooth
# Astringent
# Flat
# Tart
#
# Flavor
# Bitter
# Sweet
# Dry
# Sour
#
#
# How do we evaluate wines? What are the stages of taste?
# Appearance
# Brilliant: wines free of any visible solids and having a sparkling clarity.
# Clear: wines free of any solids but lacking the sparkling clarity of brilliant wines.
# D
#
# Section 8 Summary:
# How are wines categorized? Classification of wine
#
# The classification of wine can be based on:
#
# - Price
# - Region of production
# - Type of grape used
# - Amount of alcohol
# - Age
# - Method of production
# - Type of packaging
#
# The classification of wine can be divided into the following:
#
# - Vintage wine
# - Non-vintage wine
# - Aged wine
# - Table wine
# - Wine for cooking
# - Sparkling wine
# - Fortified wine
# - Still wine
# - Fresh wine
# - Sweet wine
# - Dessert wine
# - Dry wine
# - Light wine
# - Red wine
# - White wine
# - Rose wine
# - Champagne
# - Port
# - Sherry
# - Madeira
# - Wine cocktail
# - Draft beer
# - Bottled beer
# - Canned beer
#
# Wine is made from fermented grapes or other fruits
#
# Section 9 Summary:
# Balanced- sugar and acid are in balance
#
# Unbalanced- sweetness is greater than acidity
#
# Residual Sugar
# Dry
# Semi-Dry
# Semi- Sweet
# Sweet
# Structure
# Full-bodied
# Medium-bodied
# Light-bodied
# Alcohol
# High
# Medium
# Low
#
# Section 10 Summary:
# What is the most predominant flavor in the aroma?
# What is the most predominant flavor in the palate?
# What is the most predominant flavor in the finish?
# What is the most predominant flavor in the aftertaste?
# What is the most predominant flavor in the overall beer?
#
# You must identify the following chemical compounds: volatile esters, diacetyl, acetaldehyde, sulfur compounds, DMS, dimethyl sulfide,
#
# What are the predominant chemical compounds in the aroma?
# What are the predominant chemical compounds in the palate?
# What are the predominant chemical compounds in the finish?
# What are the predominant chemical compounds in the aftertaste?
# What are the predominant chemical compounds in the overall beer?
#
# What is the body of the beer?
# What is the texture of the beer?
# What is the
#
# Quiz Questions:
#
# Section 1 Questions:
# exchange stage for fining; reds do not white wines require malo-lactic fermentation to make them softer, but red wines do not
#
# White wine grapes are generally picked earlier than red wine grapes.
#
# What are the main differences between white and red wines in terms of aging and storage?
#
# Red wines are more stable than whites and can be aged for many years. White wines are not as stable and are generally consumed within three to five years of the vintage date.
#
# Furthermore, red wines are best stored on their sides and white wines are generally best stored on their sides.
#
# Red wines can be stored flat or on their sides.
#
# What are the primary characteristics of a wine?
#
# Appearance (color)
# Aroma (smell)
# Taste
# Finish
#
# How does a wine’s color relate to its varietal type?
#
# Section 2 Questions:
# ers, barrels, etc)
# vineyard management (techniques for harvesting grapes, fermenting, and aging)
#
#
# How many grape varieties exist and what are the major ones?
#
# There are around 5,000 grape varieties. The major ones are Chardonnay, Cabernet Sauvignon, Sauvignon Blanc, Merlot, Pinot Noir, Syrah, and Riesling.
#
# What are the different types of still white wines?
#
# Dry: A dry white wine is a wine that has little to no residual sugar.
#
# Off-Dry: An off-dry wine is a white wine that is semi sweet.
#
# Sweet: A sweet wine is a wine that contains a high amount of residual sugar.
#
# Fortified: A fortified wine is a wine that has had brandy or neutral spirit added to it
#
# Section 3 Questions:
# ine color
# White: Greenish-white, greenish-gold, amber, golden, yellow, and orange.
# Red: Red, garnet, ruby, raspberry, plum, and purple.
# Rosé: Pink, light red, salmon, and orange.
#
# What are the major differences between how white and red wines are made?
#
# Red Wine
# Most red wines are best at cool room temperature. 62-65 degrees F (16-18 degrees C).
# Red served at actual room temperature (70 degrees F) can taste flat, flabby, lifeless, and often too hot with a burning sensation from the alcohol (room temperature in the past use to be much lower, 62-65).
# Red served too cold tastes overly tannic and acidic, decidedly unpleasant.
# Light, fruity red wines are most delightful
#
# Section 4 Questions:
# yric acid may be produced)
#
# Tannins: give a feeling of dryness in the mouth
# come from skin, stalk, pips.
# add to structural balance of the wine
#
# Grape Ester- contributes to aromas and flavors
#
# Body, texture, structure, and mouthfeel
# Body: refers to the perceivable weight of the wine in the mouth
# Texture: refers to the tactile feeling of the wine in the mouth
# Structure: refers to the perception of balance, harmony, and complexity of the wine in the mouth
# Mouthfeel: refers to the overall experience of a wine in the mouth
#
# What are the major varietal categories of wine and grapes?
#
# RED TABLE WINES
# Cabernet Sauvignon:
# Zinfandel
# Merlot
#
# WHITE TABLE WINES
# Chardonnay
# Sauvignon Blanc
# Ries
#
# Section 5 Questions:
#  in cool growing regions.
#
# Acidification - the addition of acid to the unfinished wine (sometimes done in hot climates where the natural acidity in the grapes is low).
#
# Amelioration - the addition of water and sugar to the grape must to dilute acidity and to boost the alcohol in the finished wine.
#
# Adding yeast: ferments grape’s sugar and converts it to carbon dioxide and alcohol
# Removing sulfur dioxide
# Tannin: Removing tannin
# Filtration: passing wine through a filter to remove sediment that might make wine cloudy and/or to remove yeast, bacteria and other unwanted substances; also to stabilize the wine and to protect it from spoilage
# Malolactic Fermentation: a process in which malic acid can be converted to a softer lactic acid, which contributes to buttery flavors
#
# Section 6 Questions:
# ).
#
# Bouquet: fragrances developed in the wine making and aging process.
# Flavor: the color and texture of the wine
# o Fresh: fresh wines are clean, crisp, and refreshing.
# o Dry: dry wine is wine that has no residual sugar
# o Light: light wines are usually low in alcohol content
# o Bitter: bitter wines have a harsh, dry aftertaste
# o Sweet: sweet wines have a residual sugar (honey).
# o Tart: tart wines are high in acidity and only slightly sweet
# o Fruity: fruity wines give the impression of tasting like certain fruits
# o Astringent: astringent wines have a dry, puckering taste
# o Full: full wines are rich, round and full-bodied
# o Soft: soft wines lack the rough edges of harsh wines
# o Rich: rich wines
#
# Section 7 Questions:
# How do we evaluate wines? What are the stages of taste?
#
# Bitter/Harsh
# Astringent
# Fruity
# Flavors: Sensation of taste (sweet, sour, bitter, salty, umami)
# Taste: texture of wine
# Flavors and Taste:
#
# Sweetness:
#
# The wine’s perception of sweetness or lack of sweetness
#
# The sweetness is balanced with the acids and tannins in the wine (sugar/acid balance)
#
# Residual sugar: residual sugar in wine (<.4% is technically dry. Residual sugar balances high acidity. High acidity can appear dry to the taste even though they have residual sugar.
#
# Acidity:
#
# The wine’s perception of acidity or lack of acidity
#
# Balanced with the sweetness in the wine
#
# The wine’s
#
# Section 8 Questions:
#
# How do we evaluate wines? What are the characteristics of Wine?
#
# Acidity: slightly acidic, medium acidic, high acidic
# pH: 3.0 (lemon juice), 3.5 (tomato juice), 4.0 (water), 4.5 (cow’s milk), 5.0 (ripe fruit), 6.0 (filtered water), 7.0 (pure water), 8.0 (alkaline water)
# Tannin: slightly tannic, medium tannic, high tannic
# Body: light-bodied, medium-bodied, full-bodied
# Alcohol: dry, medium dry, medium sweet, sweet
# Flavors: fruity, earthy, herbal, spicy
# Aromas: fruity, floral, earthy, spicy, herbal, toasty
#
#
#
# Section 9 Questions:
# Other factors:
# Purity
# Astringency
# Tannin
# Bitterness
# Finish
# Aroma
# Complexity
# Body
#
# Balance
# Taste
# Flavor
#
# Mouthfeel
#
# Alcohol
#
# Oak
#
# Acidity
#
# Tannin
#
# Bitterness
#
# Fruit
#
# Citrus
#
# Berry
#
# Floral
#
# Spice
#
# Earth
#
# Herb
#
# Mineral
#
# Caramel
#
# Vanilla
#
# Coffee
#
# Smoke
#
# Nutty
#
# Malt
#
# Corn
#
# Oily
#
# Alcohol
#
# Heat
#
# Astringency
#
# Bitterness
#
# Sweetness
#
# Balance
#
# Body
#
# Taste
#
# Flavor
#
# Mouthfeel
#
# Acidity
#
# Oak
#
# Tannin
#
# Bitterness
#
#
#
# Section 10 Questions:
# Compare with these categories:
#
# - intensity
# - sweet
# - acidic
# - bitter
# - astringent
#
# ### Flavors
#
# Based on the 5 basic tastes, there are 3 main flavor types: sweet, sour, and salty.
#
# - Sweetness reflects natural sugars and sweeteners. It can also be used to mask astringency or bitterness.
# - Acidic flavors come from acids like citric, lactic or acetic acid, and are often used to add freshness.
# - Salty flavors come from dissolved salts, and are generally used to add a savory taste.
#
# Various ingredients also have other flavor characteristics that are more difficult to describe.
#
# - Astringency comes from tannins, which are found in red wine and some fruits like grapes, cherries and cranberries.
# - Bitterness comes from acids or al
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a3fcf7ea4f75> in <cell line: 70>()
#      68 # Run the chatbot
#      69
# ---> 70 chatbot()
#      71
#      72
#
# <ipython-input-19-a3fcf7ea4f75> in chatbot()
#      45     print(" Study Guide Chatbot!")
#      46     while True:
# ---> 47         user_input = input("Please upload your study guide (PDF/DOCX) or type 'exit'   to quit: ").strip()
#      48
#      49         if user_input.lower() == 'exit':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#unit tests
assert(extract_text_from_docx("sample.docx")=="Test")
assert(extract_text_from_pdf("sample.pdf")=="Geaux Saints")
no_questions=generate_study_guide("sample2.pdf")
questions=generate_study_guide("sample2.pdf", True)
assert(not("\nQuiz Questions:\n" in no_questions))
assert("\nQuiz Questions:\n" in questions)

# %%
\
